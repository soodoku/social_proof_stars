# %%
import os
import pandas as pd
import numpy as np
import json
import janitor

pd.set_option('display.max_columns', 120)
pd.set_option('display.max_rows', 100)

from utilities import read_jsons

# %%
# Read in 100 random sample
df_random_sample = (
    pd.read_csv("../input/random_sample.csv")
    .assign(slug=lambda df: df["github"].str.replace("https://github.com/", ""))
    .assign(slug=lambda df: df["slug"].apply(lambda x: x[:-1] if x.endswith("/") else x))
    .assign(slug=lambda df: df["slug"].str.lower().str.strip())
#     .assign(fileslug=lambda df: df["slug"].str.replace("/", "_"))
    .assign(treated=1)
    # Assign the two types
    .assign(boughtstars=lambda df: (df.index < 25).astype(int))
    .assign(treated2=lambda df: df["boughtstars"] + df["treated"])
)
df_random_sample.head(3)
# Out:
# /tmp/ipykernel_2111/2541581568.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   .assign(slug=lambda df: df["github"].str.replace("https://github.com/", ""))
#                         pkg  return_code  \
# 0  bird-ospf-link-db-parser        200.0
# 1                  asciicli        200.0
# 2           bdpotentiometer        200.0
#
#                                           github_url  \
# 0  https://github.com/Andrew-Dickinson/bird-ospf-...
# 1             https://github.com/mrq-andras/asciicli
# 2      https://github.com/bond-anton/BDPotentiometer
#
#                                         homepage     earliest_release  \
# 0                                            NaN  2023-04-29T07:23:44
# 1         https://github.com/mrq-andras/asciicli  2023-04-28T07:22:55
# 2  https://github.com/bond-anton/BDPotentiometer  2023-04-27T06:35:18
#
#    gh_url_check                                             github  \
# 0           1.0  https://github.com/Andrew-Dickinson/bird-ospf-...
# 1           1.0             https://github.com/mrq-andras/asciicli
# 2           1.0      https://github.com/bond-anton/BDPotentiometer
#
#                                                 pypi  \
# 0  https://pypi.org/project/bird-ospf-link-db-par...
# 1         https://pypi.org/project/asciicli/#history
# 2  https://pypi.org/project/bdpotentiometer/#history
#
#                                                label  \
# 0  bird-ospf-link-db-parser\r\nhttps://github.com...
# 1  asciicli\r\nhttps://github.com/mrq-andras/asci...
# 2  bdpotentiometer\r\nhttps://github.com/bond-ant...
#
#                                         slug  treated  boughtstars  treated2
# 0  andrew-dickinson/bird-ospf-link-db-parser        1            1         2
# 1                        mrq-andras/asciicli        1            1         2
# 2                 bond-anton/bdpotentiometer        1            1         2

# %%
# Repos characteristics
payloads = read_jsons("../output/repo_profile_payload/")

df_repos = (
    pd.DataFrame(payloads)
    .dropna(subset=["id"])
    .assign(slug=lambda df: df["full_name"].str.lower().str.strip())
    ## Get treatment assignment ----------------------------------------------
    .merge(df_random_sample, how="left", on="slug", validate="1:1", indicator=True)
    .assign(treated=lambda df: df["treated"].fillna(0).apply(int))
    .assign(treated2=lambda df: df["treated2"].fillna(0).apply(int))
    .assign(created_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_created=lambda df: [dt.year for dt in df["created_at"]])
    ## Cleaning up additional features ---------------------------------------
    .assign(license_str=lambda df: [license["spdx_id"] if license else None for license in df["license"]])
    .assign(n_topics=lambda df: [len(topics) for topics in df["topics"]])
    # https://stackoverflow.com/a/8679592
    .assign(size_mb=lambda df: df["size"]/1024)
    .assign(is_org=lambda df: np.where(df["organization"].isna(), 0, 1))
    .assign(user=lambda df: [slug.split("/")[0] for slug in df["slug"]])
    .assign(owner_str=lambda df: [owner["login"].lower().strip() if owner else None for owner in df["owner"]])
    .assign(description_size=lambda df: df["description"].str.len().fillna(0).apply(int))
#     ## Getting readme stats --------------------------------------------------
#     .merge((pd.read_csv("../output/pypi_readme.csv", 
#                         usecols=["slug", "n_requirements", "raw_readme_len", "processed_readme_len"])), 
#            how="left", on="slug", validate="1:1"
#           )
)
assert (df_repos["user"] == df_repos["owner_str"]).all()
display(df_repos.head(3))
df_repos.info(verbose=True)
# Out:
#             id       node_id      name             full_name private  \
# 0  632697072.0  R_kgDOJbYw8A   ezfinpy  renanmoretto/ezfinpy   False
# 1  629920730.0  R_kgDOJYvT2g  statplot   dingyizhao/statplot   False
# 2  611058264.0  R_kgDOJGwCWA  imgutils      deepghs/imgutils   False
#
#                                                owner  \
# 0  {'login': 'renanmoretto', 'id': 103861667, 'no...
# 1  {'login': 'dingyizhao', 'id': 46778380, 'node_...
# 2  {'login': 'deepghs', 'id': 126587470, 'node_id...
#
#                                   html_url  \
# 0  https://github.com/renanmoretto/ezfinpy
# 1   https://github.com/dingyizhao/statplot
# 2      https://github.com/deepghs/imgutils
#
#                                          description   fork  \
# 0                                               None  False
# 1              Common plot code used in astrophysics  False
# 2  A convenient and user-friendly anime-style ima...  False
#
#                                                  url  \
# 0  https://api.github.com/repos/renanmoretto/ezfinpy
# 1   https://api.github.com/repos/dingyizhao/statplot
# 2      https://api.github.com/repos/deepghs/imgutils
#
#                                            forks_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                             keys_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                    collaborators_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                            teams_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                            hooks_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                     issue_events_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                           events_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         branches_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                             tags_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         git_tags_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         git_refs_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                            trees_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         statuses_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                        languages_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                       stargazers_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                     contributors_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                      subscribers_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                     subscription_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                          commits_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                      git_commits_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                    issue_comment_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         contents_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                          compare_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                           merges_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                          archive_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                        downloads_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                           issues_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                            pulls_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                       milestones_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                    notifications_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                         releases_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                                      deployments_url  \
# 0  https://api.github.com/repos/renanmoretto/ezfi...
# 1  https://api.github.com/repos/dingyizhao/statpl...
# 2  https://api.github.com/repos/deepghs/imgutils/...
#
#                  created_at            updated_at             pushed_at  \
# 0 2023-04-26 00:19:26+00:00  2023-05-03T00:57:56Z  2023-05-03T19:11:09Z
# 1 2023-04-19 09:44:40+00:00  2023-04-25T08:11:21Z  2023-04-25T08:11:17Z
# 2 2023-03-08 02:32:20+00:00  2023-05-16T13:13:49Z  2023-05-18T08:56:31Z
#
#                                      git_url  \
# 0  git://github.com/renanmoretto/ezfinpy.git
# 1   git://github.com/dingyizhao/statplot.git
# 2      git://github.com/deepghs/imgutils.git
#
#                                    ssh_url  \
# 0  git@github.com:renanmoretto/ezfinpy.git
# 1   git@github.com:dingyizhao/statplot.git
# 2      git@github.com:deepghs/imgutils.git
#
#                                      clone_url  \
# 0  https://github.com/renanmoretto/ezfinpy.git
# 1   https://github.com/dingyizhao/statplot.git
# 2      https://github.com/deepghs/imgutils.git
#
#                                    svn_url  \
# 0  https://github.com/renanmoretto/ezfinpy
# 1   https://github.com/dingyizhao/statplot
# 2      https://github.com/deepghs/imgutils
#
#                             homepage_x      size  stargazers_count  \
# 0                                 None      17.0               1.0
# 1                                 None       3.0               0.0
# 2  https://deepghs.github.io/imgutils/  172568.0               2.0
#
#    watchers_count language has_issues has_projects has_downloads has_wiki  \
# 0             1.0   Python       True         True          True     True
# 1             0.0   Python       True         True          True     True
# 2             2.0   Python       True         True          True     True
#
#   has_pages has_discussions  forks_count  mirror_url archived disabled  \
# 0     False           False          0.0         NaN    False    False
# 1     False           False          0.0         NaN    False    False
# 2      True           False          0.0         NaN    False    False
#
#    open_issues_count                                            license  \
# 0                0.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 1                0.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 2                2.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
#
#   allow_forking is_template web_commit_signoff_required  \
# 0          True       False                       False
# 1          True       False                       False
# 2          True       False                       False
#
#                               topics visibility  forks  open_issues  watchers  \
# 0                                 []     public    0.0          0.0       1.0
# 1                                 []     public    0.0          0.0       0.0
# 2  [anime, image-processing, python]     public    0.0          2.0       2.0
#
#   default_branch                                        permissions  \
# 0           main  {'admin': False, 'maintain': False, 'push': Fa...
# 1           main  {'admin': False, 'maintain': False, 'push': Fa...
# 2           main  {'admin': False, 'maintain': False, 'push': Fa...
#
#   temp_clone_token  network_count  subscribers_count  \
# 0                             0.0                1.0
# 1                             0.0                1.0
# 2                             0.0                1.0
#
#                                         organization parent source message  \
# 0                                                NaN    NaN    NaN     NaN
# 1                                                NaN    NaN    NaN     NaN
# 2  {'login': 'deepghs', 'id': 126587470, 'node_id...    NaN    NaN     NaN
#
#   documentation_url template_repository                  slug  pkg  \
# 0               NaN                 NaN  renanmoretto/ezfinpy  NaN
# 1               NaN                 NaN   dingyizhao/statplot  NaN
# 2               NaN                 NaN      deepghs/imgutils  NaN
#
#    return_code github_url homepage_y earliest_release  gh_url_check github  \
# 0          NaN        NaN        NaN              NaN           NaN    NaN
# 1          NaN        NaN        NaN              NaN           NaN    NaN
# 2          NaN        NaN        NaN              NaN           NaN    NaN
#
#   pypi label  treated  boughtstars  treated2     _merge  year_created  \
# 0  NaN   NaN        0          NaN         0  left_only          2023
# 1  NaN   NaN        0          NaN         0  left_only          2023
# 2  NaN   NaN        0          NaN         0  left_only          2023
#
#   license_str  n_topics     size_mb  is_org          user     owner_str  \
# 0         MIT         0    0.016602       0  renanmoretto  renanmoretto
# 1         MIT         0    0.002930       0    dingyizhao    dingyizhao
# 2         MIT         3  168.523438       1       deepghs       deepghs
#
#    description_size
# 0                 0
# 1                37
# 2               141
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 582 entries, 0 to 581
# Data columns (total 111 columns):
#  #    Column                       Dtype
# ---   ------                       -----
#  0    id                           float64
#  1    node_id                      object
#  2    name                         object
#  3    full_name                    object
#  4    private                      object
#  5    owner                        object
#  6    html_url                     object
#  7    description                  object
#  8    fork                         object
#  9    url                          object
#  10   forks_url                    object
#  11   keys_url                     object
#  12   collaborators_url            object
#  13   teams_url                    object
#  14   hooks_url                    object
#  15   issue_events_url             object
#  16   events_url                   object
#  17   assignees_url                object
#  18   branches_url                 object
#  19   tags_url                     object
#  20   blobs_url                    object
#  21   git_tags_url                 object
#  22   git_refs_url                 object
#  23   trees_url                    object
#  24   statuses_url                 object
#  25   languages_url                object
#  26   stargazers_url               object
#  27   contributors_url             object
#  28   subscribers_url              object
#  29   subscription_url             object
#  30   commits_url                  object
#  31   git_commits_url              object
#  32   comments_url                 object
#  33   issue_comment_url            object
#  34   contents_url                 object
#  35   compare_url                  object
#  36   merges_url                   object
#  37   archive_url                  object
#  38   downloads_url                object
#  39   issues_url                   object
#  40   pulls_url                    object
#  41   milestones_url               object
#  42   notifications_url            object
#  43   labels_url                   object
#  44   releases_url                 object
#  45   deployments_url              object
#  46   created_at                   datetime64[ns, UTC]
#  47   updated_at                   object
#  48   pushed_at                    object
#  49   git_url                      object
#  50   ssh_url                      object
#  51   clone_url                    object
#  52   svn_url                      object
#  53   homepage_x                   object
#  54   size                         float64
#  55   stargazers_count             float64
#  56   watchers_count               float64
#  57   language                     object
#  58   has_issues                   object
#  59   has_projects                 object
#  60   has_downloads                object
#  61   has_wiki                     object
#  62   has_pages                    object
#  63   has_discussions              object
#  64   forks_count                  float64
#  65   mirror_url                   float64
#  66   archived                     object
#  67   disabled                     object
#  68   open_issues_count            float64
#  69   license                      object
#  70   allow_forking                object
#  71   is_template                  object
#  72   web_commit_signoff_required  object
#  73   topics                       object
#  74   visibility                   object
#  75   forks                        float64
#  76   open_issues                  float64
#  77   watchers                     float64
#  78   default_branch               object
#  79   permissions                  object
#  80   temp_clone_token             object
#  81   network_count                float64
#  82   subscribers_count            float64
#  83   organization                 object
#  84   parent                       object
#  85   source                       object
#  86   message                      object
#  87   documentation_url            object
#  88   template_repository          object
#  89   slug                         object
#  90   pkg                          object
#  91   return_code                  float64
#  92   github_url                   object
#  93   homepage_y                   object
#  94   earliest_release             object
#  95   gh_url_check                 float64
#  96   github                       object
#  97   pypi                         object
#  98   label                        object
#  99   treated                      int64
#  100  boughtstars                  float64
#  101  treated2                     int64
#  102  _merge                       category
#  103  year_created                 int64
#  104  license_str                  object
#  105  n_topics                     int64
#  106  size_mb                      float64
#  107  is_org                       int64
#  108  user                         object
#  109  owner_str                    object
#  110  description_size             int64
# dtypes: category(1), datetime64[ns, UTC](1), float64(16), int64(6), object(87)
# memory usage: 505.4+ KB

# %%
# Users characteristics
df_users = (
    pd.read_csv("../output/users_profile.csv")
    .assign(user=lambda df: df["login"].str.lower().str.strip())
    .drop_duplicates("user")
    ## Get treatment assignment
    .merge((
        df_repos
        .select_columns(["user", "treated", "treated2", "full_name"])
        .drop_duplicates(["user", "treated"])
    ), how="left", on="user", validate="1:m"
    )
    .assign(treated=lambda df: df["treated"].fillna(0).apply(int))    
    ## Cleaning up additional features
    .assign(created_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_created=lambda df: [dt.year for dt in df["created_at"]])    
    .assign(updated_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_updated=lambda df: [dt.year for dt in df["updated_at"]])    
    .assign(list_co=lambda df: np.where(df["company"].isna(), 0, 1))
    .assign(list_loc=lambda df: np.where(df["location"].isna(), 0, 1))
    .assign(list_email=lambda df: np.where(df["email"].isna(), 0, 1))
    .assign(list_blog=lambda df: np.where(df["blog"].isna(), 0, 1))
    .assign(list_bio=lambda df: np.where(df["bio"].isna(), 0, 1))
    .assign(bio_size=lambda df: df["bio"].str.len().fillna(0).apply(int))
)
display(df_users.head(3))
df_users.info(verbose=True)
# Out:
#             login        id               node_id  \
# 0         Arsybai  33319709  MDQ6VXNlcjMzMzE5NzA5
# 1      GaNiziolek  54728889  MDQ6VXNlcjU0NzI4ODg5
# 2  MihailSalnikov   2613180  MDQ6VXNlcjI2MTMxODA=
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/333197...          NaN
# 1  https://avatars.githubusercontent.com/u/547288...          NaN
# 2  https://avatars.githubusercontent.com/u/261318...          NaN
#
#                                            url  \
# 0         https://api.github.com/users/Arsybai
# 1      https://api.github.com/users/GaNiziolek
# 2  https://api.github.com/users/MihailSalnikov
#
#                             html_url  \
# 0         https://github.com/Arsybai
# 1      https://github.com/GaNiziolek
# 2  https://github.com/MihailSalnikov
#
#                                        followers_url  \
# 0     https://api.github.com/users/Arsybai/followers
# 1  https://api.github.com/users/GaNiziolek/followers
# 2  https://api.github.com/users/MihailSalnikov/fo...
#
#                                        following_url  \
# 0  https://api.github.com/users/Arsybai/following...
# 1  https://api.github.com/users/GaNiziolek/follow...
# 2  https://api.github.com/users/MihailSalnikov/fo...
#
#                                            gists_url  \
# 0  https://api.github.com/users/Arsybai/gists{/gi...
# 1  https://api.github.com/users/GaNiziolek/gists{...
# 2  https://api.github.com/users/MihailSalnikov/gi...
#
#                                          starred_url  \
# 0  https://api.github.com/users/Arsybai/starred{/...
# 1  https://api.github.com/users/GaNiziolek/starre...
# 2  https://api.github.com/users/MihailSalnikov/st...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/Arsybai/subscript...
# 1  https://api.github.com/users/GaNiziolek/subscr...
# 2  https://api.github.com/users/MihailSalnikov/su...
#
#                                   organizations_url  \
# 0         https://api.github.com/users/Arsybai/orgs
# 1      https://api.github.com/users/GaNiziolek/orgs
# 2  https://api.github.com/users/MihailSalnikov/orgs
#
#                                            repos_url  \
# 0         https://api.github.com/users/Arsybai/repos
# 1      https://api.github.com/users/GaNiziolek/repos
# 2  https://api.github.com/users/MihailSalnikov/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/Arsybai/events{/p...
# 1  https://api.github.com/users/GaNiziolek/events...
# 2  https://api.github.com/users/MihailSalnikov/ev...
#
#                                  received_events_url  type  site_admin  \
# 0  https://api.github.com/users/Arsybai/received_...  User       False
# 1  https://api.github.com/users/GaNiziolek/receiv...  User       False
# 2  https://api.github.com/users/MihailSalnikov/re...  User       False
#
#                name        company                           blog   location  \
# 0           Arsybai       Clee Ltd             http://arsybai.com  indonesia
# 1  Gabriel Niziolek  @TempoX-Ltda                             NaN     Brazil
# 2  Mikhail Salnikov      NLP Group  https://medium.com/@MSalnikov        NaN
#
#             email hireable                                                bio  \
# 0  me@arsybai.com      NaN                 Just want to death by cuteness\r\n
# 1             NaN      NaN  Software Developer on TempoX | Django | Pyrami...
# 2             NaN     True                           Researcher in DL and NLP
#
#   twitter_username  public_repos  public_gists  followers  following  \
# 0              NaN            36             0         64          7
# 1        gniziolek            25             3          6         15
# 2              NaN            27            24          7          2
#
#                  created_at                updated_at  \
# 0 2017-11-02 12:38:27+00:00 2017-11-02 12:38:27+00:00
# 1 2019-08-31 00:19:09+00:00 2019-08-31 00:19:09+00:00
# 2 2012-10-21 15:03:02+00:00 2012-10-21 15:03:02+00:00
#
#                retrieval_date            user  treated  treated2  \
# 0  2023-05-20 21:41:26.180953         arsybai        0       0.0
# 1  2023-05-20 21:41:26.180953      ganiziolek        1       1.0
# 2  2023-05-20 21:41:26.180953  mihailsalnikov        0       0.0
#
#                    full_name  year_created  year_updated  list_co  list_loc  \
# 0      Arsybai/Jawa-Language          2017          2017        1         1
# 1       GaNiziolek/FoccoERPy          2019          2019        1         1
# 2  MihailSalnikov/EvaluateQA          2012          2012        1         0
#
#    list_email  list_blog  list_bio  bio_size
# 0           1          1         1        32
# 1           0          0         1        68
# 2           0          1         1        24
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545 entries, 0 to 544
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   login                545 non-null    object
#  1   id                   545 non-null    int64
#  2   node_id              545 non-null    object
#  3   avatar_url           545 non-null    object
#  4   gravatar_id          0 non-null      float64
#  5   url                  545 non-null    object
#  6   html_url             545 non-null    object
#  7   followers_url        545 non-null    object
#  8   following_url        545 non-null    object
#  9   gists_url            545 non-null    object
#  10  starred_url          545 non-null    object
#  11  subscriptions_url    545 non-null    object
#  12  organizations_url    545 non-null    object
#  13  repos_url            545 non-null    object
#  14  events_url           545 non-null    object
#  15  received_events_url  545 non-null    object
#  16  type                 545 non-null    object
#  17  site_admin           545 non-null    bool
#  18  name                 440 non-null    object
#  19  company              148 non-null    object
#  20  blog                 252 non-null    object
#  21  location             289 non-null    object
#  22  email                176 non-null    object
#  23  hireable             88 non-null     object
#  24  bio                  261 non-null    object
#  25  twitter_username     105 non-null    object
#  26  public_repos         545 non-null    int64
#  27  public_gists         545 non-null    int64
#  28  followers            545 non-null    int64
#  29  following            545 non-null    int64
#  30  created_at           545 non-null    datetime64[ns, UTC]
#  31  updated_at           545 non-null    datetime64[ns, UTC]
#  32  retrieval_date       545 non-null    object
#  33  user                 545 non-null    object
#  34  treated              545 non-null    int64
#  35  treated2             542 non-null    float64
#  36  full_name            542 non-null    object
#  37  year_created         545 non-null    int64
#  38  year_updated         545 non-null    int64
#  39  list_co              545 non-null    int64
#  40  list_loc             545 non-null    int64
#  41  list_email           545 non-null    int64
#  42  list_blog            545 non-null    int64
#  43  list_bio             545 non-null    int64
#  44  bio_size             545 non-null    int64
# dtypes: bool(1), datetime64[ns, UTC](2), float64(2), int64(14), object(26)
# memory usage: 192.1+ KB

# %%
df_users["user"].nunique()
# Out:
# 537

# %%
df_users.duplicated(subset="login", keep="first").sum()
# Out:
# 8

# %%
df_users[df_users.duplicated(subset="login", keep=False)][["user", "full_name", "treated"]]
# Out:
#               user                                   full_name  treated
# 12             oca                              OCA/e-commerce        0
# 13             oca                OCA/stock-logistics-workflow        1
# 15   brightway-lca                 brightway-lca/bw_temporalis        1
# 16   brightway-lca                brightway-lca/bw_graph_tools        0
# 31     openvoiceos                OpenVoiceOS/ovos-classifiers        0
# 32     openvoiceos                         OpenVoiceOS/jurebes        1
# 129    hansalemaos                 hansalemaos/multisubprocess        0
# 130    hansalemaos  hansalemaos/locate_pixelcolor_cythonsingle        1
# 182     yuanjie-ai                     yuanjie-ai/stopwords-zh        0
# 183     yuanjie-ai                          yuanjie-ai/ChatLLM        1
# 207     nielathome                          nielathome/Phoenix        1
# 208     nielathome                              nielathome/nlv        0
# 296          vsego                             vsego/call-args        1
# 297          vsego                             vsego/deep-vars        0
# 351            ibm                             IBM/py-to-proto        0
# 352            ibm                                  IBM/docAMR        1

# %%
df_repos.select_columns("treated").to_csv("../output/repo_baselines.csv", index=False)
df_users.to_csv("../output/user_baselines.csv", index=False)

# %%
(df_repos
 .select_columns(["year_created", "fork", "treated", "treated2", "size_mb", 'stargazers_count',
 'watchers_count',
 'language', 'has_issues', 'forks', 'open_issues', 'subscribers_count', 'n_topics'])
 .assign(fork=lambda df: np.where(df["fork"], 1, 0))
 .assign(has_issues=lambda df: np.where(df["has_issues"], 1, 0))
 .to_stata("../output/repo_baselines.dta", write_index=False)
)

# %%
(df_users
 .select_columns(["treated", "treated2", "type", "public_repos", "public_gists", 
                  "followers", "following", "year_created", "year_updated", "list_co", 
                  'list_email', 'list_blog', 'list_bio',  'bio_size'])
#  .assign(fork=lambda df: np.where(df["fork"], 1, 0))
#  .assign(has_issues=lambda df: np.where(df["has_issues"], 1, 0))
 .to_stata("../output/user_baselines.dta", write_index=False)
)
