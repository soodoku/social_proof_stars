# %%
import pandas as pd

# %%
df = (
    pd.read_csv("../input/check-github-url.csv")
    .query("gh_url_check==1")
    .reset_index(drop=True)
)
df
# Out:
#                                                    pkg  return_code
# 0                                             jawalang        200.0  \
# 1                                            foccoerpy        200.0
# 2                                           evaluateqa        200.0
# 3                                 sa-node-architecture        200.0
# 4                                 micropython-icm20948        200.0
# ..                                                 ...          ...
# 617  odoo-addon-purchase-order-qty-by-product-category        200.0
# 618                                  print-pretty-tree        200.0
# 619                                          epcrawler        200.0
# 620                           andeplane-pyodide-kernel        200.0
# 621                                        conplex-dti        200.0
#
#                                             github_url
# 0             https://github.com/Arsybai/jawa-language  \
# ...
