# %%
import os
import pandas as pd
import json
import janitor

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

from utilities import read_jsons

# %%
# Read in 100 random sample 
df_random_sample = (
    pd.read_csv("../input/random_sample.csv")
    .assign(slug=lambda df: df["github"].str.replace("https://github.com/", ""))
    .assign(slug=lambda df: df["slug"].apply(lambda x: x[:-1] if x.endswith("/") else x))
    .assign(slug=lambda df: df["slug"].str.lower().str.strip())
    .assign(treated=1)
)
df_random_sample.head(3)
# Out:
#                         pkg  return_code
# 0  bird-ospf-link-db-parser        200.0  \
# 1                  asciicli        200.0
# 2           bdpotentiometer        200.0
#
#                                           github_url
# 0  https://github.com/Andrew-Dickinson/bird-ospf-...  \
# 1             https://github.com/mrq-andras/asciicli
# 2      https://github.com/bond-anton/BDPotentiometer
#
#                                         homepage     earliest_release
# 0                                            NaN  2023-04-29T07:23:44  \
# 1         https://github.com/mrq-andras/asciicli  2023-04-28T07:22:55
# 2  https://github.com/bond-anton/BDPotentiometer  2023-04-27T06:35:18
#
#    gh_url_check                                             github
# 0           1.0  https://github.com/Andrew-Dickinson/bird-ospf-...  \
# 1           1.0             https://github.com/mrq-andras/asciicli
# 2           1.0      https://github.com/bond-anton/BDPotentiometer
#
#                                                 pypi
# 0  https://pypi.org/project/bird-ospf-link-db-par...  \
# 1         https://pypi.org/project/asciicli/#history
# 2  https://pypi.org/project/bdpotentiometer/#history
#
#                                                label
# 0  bird-ospf-link-db-parser\nhttps://github.com/A...  \
# 1  asciicli\nhttps://github.com/mrq-andras/asciic...
# 2  bdpotentiometer\nhttps://github.com/bond-anton...
#
#                                         slug  treated
# 0  andrew-dickinson/bird-ospf-link-db-parser        1
# 1                        mrq-andras/asciicli        1
# 2                 bond-anton/bdpotentiometer        1

# %%
# Repos characteristics
payloads = read_jsons("../output/repo_profile_payload/")

df_repos = (
    pd.DataFrame(payloads)
    .dropna(subset=["id"], ignore_index=True)
    .assign(slug=lambda df: df["full_name"].str.lower().str.strip())
    .assign(user=lambda df: [slug.split("/")[0] for slug in df["slug"]])
    .assign(license_str=lambda df: [license["spdx_id"] if license else None for license in df["license"]])
    .assign(owner_str=lambda df: [owner["login"].lower().strip() if owner else None for owner in df["owner"]])
    .merge(df_random_sample, how="left", on="slug", validate="1:1", indicator=True)
    .assign(treated=lambda df: df["treated"].fillna(0).apply(int))
    .assign(created_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_created=lambda df: [dt.year for dt in df["created_at"]])
)
assert (df_repos["user"] == df_repos["owner_str"]).all()
df_repos.head()
# Out:
#             id                           node_id             name
# 0  629516002.0                      R_kgDOJYWm4g        dustpylib  \
# 1  633593525.0                      R_kgDOJcPetQ       enerbitdso
# 2  625298831.0                      R_kgDOJUVNjw          rosetta
# 3  632454055.0                      R_kgDOJbJ7pw  datatable-faker
# 4  113766139.0  MDEwOlJlcG9zaXRvcnkxMTM3NjYxMzk=       server-env
#
#                        full_name private
# 0             stammler/dustpylib   False  \
# 1             enerBit/enerbitdso   False
# 2                ayman-m/rosetta   False
# 3  Agent-Hellboy/datatable-faker   False
# 4                 OCA/server-env   False
#
#                                                owner
# 0  {'login': 'stammler', 'id': 21321343, 'node_id...  \
# 1  {'login': 'enerBit', 'id': 97300957, 'node_id'...
# 2  {'login': 'ayman-m', 'id': 57979775, 'node_id'...
# 3  {'login': 'Agent-Hellboy', 'id': 31388347, 'no...
# 4  {'login': 'OCA', 'id': 7600578, 'node_id': 'MD...
#
#                                            html_url
# 0             https://github.com/stammler/dustpylib  \
# 1             https://github.com/enerBit/enerbitdso
# 2                https://github.com/ayman-m/rosetta
# 3  https://github.com/Agent-Hellboy/datatable-faker
# 4                 https://github.com/OCA/server-env
#
#                                          description   fork
# 0          Library with auxiliary modules for DustPy  False  \
# 1                                               None  False
# 2  Rosetta is a Python library that allows you to...  False
# 3    Library to generate fake datatable for unittest  False
# 4  Tools to manage environment-dependent configur...  False
#
#                                                  url
# 0    https://api.github.com/repos/stammler/dustpylib  \
# 1    https://api.github.com/repos/enerBit/enerbitdso
# 2       https://api.github.com/repos/ayman-m/rosetta
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4        https://api.github.com/repos/OCA/server-env
#
#                                            forks_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/f...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/forks
#
#                                             keys_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/k...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/ke...
#
#                                    collaborators_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                            teams_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/t...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/teams
#
#                                            hooks_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/h...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/hooks
#
#                                     issue_events_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/i...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/is...
#
#                                           events_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/e...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/ev...
#
#                                        assignees_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/a...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/as...
#
#                                         branches_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/b...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/br...
#
#                                             tags_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/tags
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4   https://api.github.com/repos/OCA/server-env/tags
#
#                                            blobs_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/g...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/gi...
#
#                                         git_tags_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/g...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/gi...
#
#                                         git_refs_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/g...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/gi...
#
#                                            trees_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/g...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/gi...
#
#                                         statuses_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/s...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/st...
#
#                                        languages_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/l...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/la...
#
#                                       stargazers_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/s...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/st...
#
#                                     contributors_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                      subscribers_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/s...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/su...
#
#                                     subscription_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/s...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/su...
#
#                                          commits_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                      git_commits_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/g...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/gi...
#
#                                         comments_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                    issue_comment_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/i...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/is...
#
#                                         contents_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                          compare_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/c...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/co...
#
#                                           merges_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/m...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/me...
#
#                                          archive_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/{...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/{a...
#
#                                        downloads_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/d...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/do...
#
#                                           issues_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/i...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/is...
#
#                                            pulls_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/p...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/pu...
#
#                                       milestones_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/m...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/mi...
#
#                                    notifications_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/n...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/no...
#
#                                           labels_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/l...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/la...
#
#                                         releases_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/r...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/re...
#
#                                      deployments_url
# 0  https://api.github.com/repos/stammler/dustpyli...  \
# 1  https://api.github.com/repos/enerBit/enerbitds...
# 2  https://api.github.com/repos/ayman-m/rosetta/d...
# 3  https://api.github.com/repos/Agent-Hellboy/dat...
# 4  https://api.github.com/repos/OCA/server-env/de...
#
#                  created_at            updated_at             pushed_at
# 0 2023-04-18 13:22:25+00:00  2023-04-27T17:59:43Z  2023-05-19T21:00:15Z  \
# 1 2023-04-27 21:15:37+00:00  2023-04-27T21:16:33Z  2023-04-27T22:23:56Z
# 2 2023-04-08 17:19:59+00:00  2023-04-22T14:44:34Z  2023-04-26T16:38:29Z
# 3 2023-04-25 12:47:24+00:00  2023-04-25T12:52:05Z  2023-04-27T07:25:50Z
# 4 2017-12-10 16:40:13+00:00  2023-05-10T12:05:49Z  2023-04-29T07:38:04Z
#
#                                              git_url  ... stargazers_count
# 0            git://github.com/stammler/dustpylib.git  ...              0.0  \
# 1            git://github.com/enerBit/enerbitdso.git  ...              0.0
# 2               git://github.com/ayman-m/rosetta.git  ...              0.0
# 3  git://github.com/Agent-Hellboy/datatable-faker...  ...              0.0
# 4                git://github.com/OCA/server-env.git  ...             44.0
#
#   watchers_count language has_issues  has_projects  has_downloads  has_wiki
# 0            0.0   Python       True          True           True      True  \
# 1            0.0   Python       True          True           True      True
# 2            0.0   Python       True          True           True      True
# 3            0.0   Python       True          True           True      True
# 4           44.0     HTML       True          True           True      True
#
#   has_pages has_discussions forks_count mirror_url archived disabled
# 0     False           False         0.0        NaN    False    False  \
# 1     False           False         0.0        NaN    False    False
# 2     False           False         0.0        NaN    False    False
# 3     False           False         0.0        NaN    False    False
# 4     False           False       126.0        NaN    False    False
#
#   open_issues_count                                            license
# 0               0.0  {'key': 'bsd-3-clause', 'name': 'BSD 3-Clause ...  \
# 1               0.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 2               0.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 3               0.0  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 4              11.0  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...
#
#    allow_forking is_template web_commit_signoff_required
# 0           True       False                       False  \
# 1           True       False                       False
# 2           True       False                       False
# 3           True       False                       False
# 4           True       False                       False
#
#                                       topics visibility  forks open_issues
# 0  [astrophysics, planetary-science, python]     public    0.0         0.0  \
# 1                                         []     public    0.0         0.0
# 2                                         []     public    0.0         0.0
# 3                                         []     public    0.0         0.0
# 4                                         []     public  126.0        11.0
#
#   watchers default_branch                                        permissions
# 0      0.0           main  {'admin': False, 'maintain': False, 'push': Fa...  \
# 1      0.0           main  {'admin': False, 'maintain': False, 'push': Fa...
# 2      0.0           main  {'admin': False, 'maintain': False, 'push': Fa...
# 3      0.0           main  {'admin': False, 'maintain': False, 'push': Fa...
# 4     44.0           16.0  {'admin': False, 'maintain': False, 'push': Fa...
#
#    temp_clone_token  network_count  subscribers_count
# 0                              0.0                2.0  \
# 1                              0.0                1.0
# 2                              0.0                1.0
# 3                              0.0                1.0
# 4                            126.0               38.0
#
#                                         organization parent source  message
# 0                                                NaN    NaN    NaN      NaN  \
# 1  {'login': 'enerBit', 'id': 97300957, 'node_id'...    NaN    NaN      NaN
# 2                                                NaN    NaN    NaN      NaN
# 3                                                NaN    NaN    NaN      NaN
# 4  {'login': 'OCA', 'id': 7600578, 'node_id': 'MD...    NaN    NaN      NaN
#
#    documentation_url template_repository                           slug
# 0                NaN                 NaN             stammler/dustpylib  \
# 1                NaN                 NaN             enerbit/enerbitdso
# 2                NaN                 NaN                ayman-m/rosetta
# 3                NaN                 NaN  agent-hellboy/datatable-faker
# 4                NaN                 NaN                 oca/server-env
#
#             user   license_str      owner_str  pkg return_code github_url
# 0       stammler  BSD-3-Clause       stammler  NaN         NaN        NaN  \
# 1        enerbit           MIT        enerbit  NaN         NaN        NaN
# 2        ayman-m           MIT        ayman-m  NaN         NaN        NaN
# 3  agent-hellboy           MIT  agent-hellboy  NaN         NaN        NaN
# 4            oca      AGPL-3.0            oca  NaN         NaN        NaN
#
#   homepage_y earliest_release gh_url_check  github pypi label treated
# 0        NaN              NaN          NaN     NaN  NaN   NaN       0  \
# 1        NaN              NaN          NaN     NaN  NaN   NaN       0
# 2        NaN              NaN          NaN     NaN  NaN   NaN       0
# 3        NaN              NaN          NaN     NaN  NaN   NaN       0
# 4        NaN              NaN          NaN     NaN  NaN   NaN       0
#
#       _merge year_created
# 0  left_only         2023
# 1  left_only         2023
# 2  left_only         2023
# 3  left_only         2023
# 4  left_only         2017
#
# [5 rows x 105 columns]

# %%
# Users characteristics
df_users = (
    pd.read_csv("../output/users_profile.csv")
    .assign(user=lambda df: df["login"].str.lower().str.strip())
    .drop_duplicates("user")
    .merge((
        df_repos
        .select_columns(["user", "treated"])
        .drop_duplicates(["user", "treated"])
    ), how="left", on="user", validate="1:m"
    )
    .assign(treated=lambda df: df["treated"].fillna(0).apply(int))    
    .assign(created_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_created=lambda df: [dt.year for dt in df["created_at"]])    
    .assign(updated_at=lambda df: pd.to_datetime(df['created_at']))
    .assign(year_updated=lambda df: [dt.year for dt in df["updated_at"]])
)
df_users.head()
# Out:
#                login         id               node_id
# 0            Arsybai   33319709  MDQ6VXNlcjMzMzE5NzA5  \
# 1         GaNiziolek   54728889  MDQ6VXNlcjU0NzI4ODg5
# 2     MihailSalnikov    2613180  MDQ6VXNlcjI2MTMxODA=
# 3  Simply-Artificial  130693929          O_kgDOB8o7KQ
# 4      jposada202020   34255413  MDQ6VXNlcjM0MjU1NDEz
#
#                                           avatar_url  gravatar_id
# 0  https://avatars.githubusercontent.com/u/333197...          NaN  \
# 1  https://avatars.githubusercontent.com/u/547288...          NaN
# 2  https://avatars.githubusercontent.com/u/261318...          NaN
# 3  https://avatars.githubusercontent.com/u/130693...          NaN
# 4  https://avatars.githubusercontent.com/u/342554...          NaN
#
#                                               url
# 0            https://api.github.com/users/Arsybai  \
# 1         https://api.github.com/users/GaNiziolek
# 2     https://api.github.com/users/MihailSalnikov
# 3  https://api.github.com/users/Simply-Artificial
# 4      https://api.github.com/users/jposada202020
#
#                                html_url
# 0            https://github.com/Arsybai  \
# 1         https://github.com/GaNiziolek
# 2     https://github.com/MihailSalnikov
# 3  https://github.com/Simply-Artificial
# 4      https://github.com/jposada202020
#
#                                        followers_url
# 0     https://api.github.com/users/Arsybai/followers  \
# 1  https://api.github.com/users/GaNiziolek/followers
# 2  https://api.github.com/users/MihailSalnikov/fo...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/fol...
#
#                                        following_url
# 0  https://api.github.com/users/Arsybai/following...  \
# 1  https://api.github.com/users/GaNiziolek/follow...
# 2  https://api.github.com/users/MihailSalnikov/fo...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/fol...
#
#                                            gists_url
# 0  https://api.github.com/users/Arsybai/gists{/gi...  \
# 1  https://api.github.com/users/GaNiziolek/gists{...
# 2  https://api.github.com/users/MihailSalnikov/gi...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/gis...
#
#                                          starred_url
# 0  https://api.github.com/users/Arsybai/starred{/...  \
# 1  https://api.github.com/users/GaNiziolek/starre...
# 2  https://api.github.com/users/MihailSalnikov/st...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/sta...
#
#                                    subscriptions_url
# 0  https://api.github.com/users/Arsybai/subscript...  \
# 1  https://api.github.com/users/GaNiziolek/subscr...
# 2  https://api.github.com/users/MihailSalnikov/su...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/sub...
#
#                                    organizations_url
# 0          https://api.github.com/users/Arsybai/orgs  \
# 1       https://api.github.com/users/GaNiziolek/orgs
# 2   https://api.github.com/users/MihailSalnikov/orgs
# 3  https://api.github.com/users/Simply-Artificial...
# 4    https://api.github.com/users/jposada202020/orgs
#
#                                            repos_url
# 0         https://api.github.com/users/Arsybai/repos  \
# 1      https://api.github.com/users/GaNiziolek/repos
# 2  https://api.github.com/users/MihailSalnikov/repos
# 3  https://api.github.com/users/Simply-Artificial...
# 4   https://api.github.com/users/jposada202020/repos
#
#                                           events_url
# 0  https://api.github.com/users/Arsybai/events{/p...  \
# 1  https://api.github.com/users/GaNiziolek/events...
# 2  https://api.github.com/users/MihailSalnikov/ev...
# 3  https://api.github.com/users/Simply-Artificial...
# 4  https://api.github.com/users/jposada202020/eve...
#
#                                  received_events_url          type
# 0  https://api.github.com/users/Arsybai/received_...          User  \
# 1  https://api.github.com/users/GaNiziolek/receiv...          User
# 2  https://api.github.com/users/MihailSalnikov/re...          User
# 3  https://api.github.com/users/Simply-Artificial...  Organization
# 4  https://api.github.com/users/jposada202020/rec...          User
#
#    site_admin                name        company
# 0       False             Arsybai       Clee Ltd  \
# 1       False    Gabriel Niziolek  @TempoX-Ltda
# 2       False    Mikhail Salnikov      NLP Group
# 3       False  Simply Artificial             NaN
# 4       False       jposada202020            NaN
#
#                                      blog   location
# 0                      http://arsybai.com  indonesia  \
# 1                                     NaN     Brazil
# 2           https://medium.com/@MSalnikov        NaN
# 3                                     NaN        NaN
# 4  https://mastodon.social/@jposada202020        NaN
#
#                                email hireable
# 0                     me@arsybai.com      NaN  \
# 1                                NaN      NaN
# 2                                NaN     True
# 3  simply-artificial@itsmealfie0.com      NaN
# 4                                NaN      NaN
#
#                                                  bio twitter_username
# 0                 Just want to death by cuteness\r\n              NaN  \
# 1  Software Developer on TempoX | Django | Pyrami...        gniziolek
# 2                           Researcher in DL and NLP              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#    public_repos  public_gists  followers  following                created_at
# 0            36             0         64          7 2017-11-02 12:38:27+00:00  \
# 1            25             3          6         15 2019-08-31 00:19:09+00:00
# 2            27            24          7          2 2012-10-21 15:03:02+00:00
# 3             2             0          1          0 2023-04-13 17:37:21+00:00
# 4            41             5         11          7 2017-12-05 00:05:32+00:00
#
#                  updated_at              retrieval_date               user
# 0 2017-11-02 12:38:27+00:00  2023-05-20 21:41:26.180953            arsybai  \
# 1 2019-08-31 00:19:09+00:00  2023-05-20 21:41:26.180953         ganiziolek
# 2 2012-10-21 15:03:02+00:00  2023-05-20 21:41:26.180953     mihailsalnikov
# 3 2023-04-13 17:37:21+00:00  2023-05-20 21:41:26.180953  simply-artificial
# 4 2017-12-05 00:05:32+00:00  2023-05-20 21:41:26.180953      jposada202020
#
#    treated  year_created  year_updated
# 0        0          2017          2017
# 1        1          2019          2019
# 2        0          2012          2012
# 3        0          2023          2023
# 4        0          2017          2017

# %%
df_repos.to_csv("../output/repo_baselines.csv", index=False)
df_users.to_csv("../output/user_baselines.csv", index=False)
