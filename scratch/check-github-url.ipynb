# %%
import pandas as pd
import janitor
from urllib.parse import urlparse
from tqdm.notebook import tqdm
import requests
import time
import random

# %%
def is_github_repo_path(url: str) -> bool:
    """Check whether a URL is a link to a GitHub repository.
    
    GitHub repositories have a username and a repo name.
    Example: github.com/<user>/<repo>
    
    Parameters
    ----------
    url: str
        URL to check.
        
    Raises
    ------
    AssertionError
        Raises AssertionError when URL is not a github repo URL.
        
    Returns
    -------
    None
    """
    try:
        parsed_url = urlparse(url)
    except AttributeError:
        return False
    
    # Assert that domain is GitHub
    try:
        assert parsed_url.netloc == "github.com"
    except AssertionError:
        return False
    
    # Assert that the path is of the form /<user>/<repo>
    path_components = parsed_url.path.split("/")
    
    try:
        assert len(path_components)==3  # first component is ""
    except AssertionError:
        return False
    return True

# %%
def url_exists(url: str) -> bool:
    """Checks if URL exists.
    
    Parameters
    ----------
    url: str
        URL to check.
        
    Returns
    -------
    bool
        True if URL exists.
    """
    response = requests.head(url)
    return response.status_code == requests.codes.ok

# %%
df = (
    pd.read_csv("new-pkg-30April-24April.csv")
    .query("github_url==github_url | homepage==homepage")
    .reset_index(drop=True)
)
df
# Out:
#                            pkg  return_code
# 0                   gpt-review        200.0  \
# 1    pixivspidercreatedbyhanxu        200.0
# 2       text-content-generator        200.0
# 3                     jawalang        200.0
# 4               gvec-to-python        200.0
# ..                         ...          ...
# 961              skeleton-plot        200.0
# 962          drb-topic-geojson        200.0
# 963       wagtail-sb-codefield        200.0
# 964                conplex-dti        200.0
# 965             marqeta-client        200.0
#
#                                             github_url
# 0        https://github.com/dciborow/action-gpt/issues  \
# 1                                                  NaN
# 2    https://github.com/mheshze/TextContentGenerati...
# 3             https://github.com/Arsybai/jawa-language
# 4                       https://github.com/me/spam.git
# ..                                                 ...
# 961    https://github.com/AllenInstitute/skeleton_plot
# 962                                                NaN
# 963                                                NaN
# 964               https://github.com/samsledje/ConPLex
# 965       https://github.com/marqeta-client/SwadeshInc
#
#                                               homepage     earliest_release
# 0                                                  NaN  2023-04-25T22:54:54
# 1          https://gitee.com/UnderTurrets/pixiv-spider  2023-04-23T13:32:51
# 2                                                  NaN  2023-04-24T08:11:28
# 3             https://github.com/Arsybai/jawa-language  2023-04-25T00:08:33
# 4                                                  NaN  2023-04-26T07:46:17
# ..                                                 ...                  ...
# 961    https://github.com/AllenInstitute/skeleton_plot  2023-04-24T19:08:22
# 962       https://gitlab.com/drb-python/topics/geojson  2023-04-25T09:26:05
# 963  https://gitlab.com/softbutterfly/open-source/w...  2023-04-29T10:00:13
# 964               https://github.com/samsledje/ConPLex  2023-04-27T20:34:20
# 965       https://github.com/marqeta-client/SwadeshInc  2023-04-24T13:01:41
#
# [966 rows x 5 columns]

# %%
for ix, row in tqdm(df.iterrows()):
    github_url = row["github_url"]
    homepage = row["homepage"]
    
    if is_github_repo_path(github_url):
        url = github_url
    elif is_github_repo_path(homepage):
        url = homepage
    else:
        df.at[ix, "gh_url_check"] = 0
        continue
        
    if url_exists(url):
        df.at[ix, "gh_url_check"] = 1
        df.at[ix, "github"] = url
    time.sleep(random.random())
# Out:
# 0it [00:00, ?it/s]

# %%
df.query("gh_url_check==1")
# Out:
#                                                    pkg  return_code
# 3                                             jawalang        200.0  \
# 5                                            foccoerpy        200.0
# 6                                           evaluateqa        200.0
# 8                                 sa-node-architecture        200.0
# 11                                micropython-icm20948        200.0
# ..                                                 ...          ...
# 955  odoo-addon-purchase-order-qty-by-product-category        200.0
# 957                                  print-pretty-tree        200.0
# 958                                          epcrawler        200.0
# 960                           andeplane-pyodide-kernel        200.0
# 964                                        conplex-dti        200.0
#
#                                             github_url
# 3             https://github.com/Arsybai/jawa-language  \
# 5              https://github.com/GaNiziolek/FoccoERPy
# 6         https://github.com/MihailSalnikov/EvaluateQA
# 8    https://github.com/Simply-Artificial/NodeArchi...
# 11   https://github.com/jposada202020/MicroPython_I...
# ..                                                 ...
# 955           https://github.com/OCA/purchase-workflow
# 957       https://github.com/itsbrex/print-pretty-tree
# 958            https://github.com/dgsmiley18/epcrawler
# 960      https://github.com/jupyterlite/pyodide-kernel
# 964               https://github.com/samsledje/ConPLex
#
#                                               homepage     earliest_release
# 3             https://github.com/Arsybai/jawa-language  2023-04-25T00:08:33  \
# 5                                                  NaN  2023-04-25T13:26:24
# 6         https://github.com/MihailSalnikov/EvaluateQA  2023-04-26T12:10:16
# 8    https://github.com/Simply-Artificial/NodeArchi...  2023-04-27T17:03:58
# 11                                                 NaN  2023-04-26T13:51:25
# ..                                                 ...                  ...
# 955           https://github.com/OCA/purchase-workflow  2023-04-26T10:04:52
# 957       https://github.com/itsbrex/print-pretty-tree  2023-04-26T17:30:53
# 958            https://github.com/dgsmiley18/epcrawler  2023-04-25T22:16:00
# 960                                                NaN  2023-04-28T18:04:56
# 964               https://github.com/samsledje/ConPLex  2023-04-27T20:34:20
#
#      gh_url_check                                             github
# 3             1.0           https://github.com/Arsybai/jawa-language
# 5             1.0            https://github.com/GaNiziolek/FoccoERPy
# 6             1.0       https://github.com/MihailSalnikov/EvaluateQA
# 8             1.0  https://github.com/Simply-Artificial/NodeArchi...
# 11            1.0  https://github.com/jposada202020/MicroPython_I...
# ..            ...                                                ...
# 955           1.0           https://github.com/OCA/purchase-workflow
# 957           1.0       https://github.com/itsbrex/print-pretty-tree
# 958           1.0            https://github.com/dgsmiley18/epcrawler
# 960           1.0      https://github.com/jupyterlite/pyodide-kernel
# 964           1.0               https://github.com/samsledje/ConPLex
#
# [607 rows x 7 columns]

# %%
df.head(25)
# Out:
#                                         pkg  return_code
# 0                                gpt-review        200.0  \
# 1                 pixivspidercreatedbyhanxu        200.0
# 2                    text-content-generator        200.0
# 3                                  jawalang        200.0
# 4                            gvec-to-python        200.0
# 5                                 foccoerpy        200.0
# 6                                evaluateqa        200.0
# 7   certora-cli-alpha-shelly-certoraclibeta        200.0
# 8                      sa-node-architecture        200.0
# 9                        ebyte-lora-e22-rpi        200.0
# 10                         nci-cidc-schemas        200.0
# 11                     micropython-icm20948        200.0
# 12                                   jnb2py        200.0
# 13                            secure-logger        200.0
# 14                             tunnelvision        200.0
# 15                              pingsafecli        200.0
# 16                               ipytextual        200.0
# 17                               qtapputils        200.0
# 18                            napari-sam4is        200.0
# 19                                acs-axiom        200.0
# 20                           geoshaha-haoyu        200.0
# 21                             georef-ar-py        200.0
# 22       odoo-addon-stock-location-position        200.0
# 23                                     nail        200.0
# 24              local-logger-python-backend        200.0
#
#                                            github_url
# 0       https://github.com/dciborow/action-gpt/issues  \
# 1                                                 NaN
# 2   https://github.com/mheshze/TextContentGenerati...
# 3            https://github.com/Arsybai/jawa-language
# 4                      https://github.com/me/spam.git
# 5             https://github.com/GaNiziolek/FoccoERPy
# 6        https://github.com/MihailSalnikov/EvaluateQA
# 7                                                 NaN
# 8   https://github.com/Simply-Artificial/NodeArchi...
# 9                                                 NaN
# 10           https://github.com/NCI-CIDC/cidc-schemas
# 11  https://github.com/jposada202020/MicroPython_I...
# 12             https://github.com/subhranil2605/nb2py
# 13           https://github.com/lpm0073/secure-logger
# 14             https://github.com/sluijs/tunnelvision
# 15            https://github.com/bridgecrewio/checkov
# 16        https://github.com/davidbrochart/ipytextual
# 17        https://github.com/jnsebgosselin/qtapputils
# 18  https://github.com/hiroalchem/napari-SAM4IS/is...
# 19         https://github.com/AusClimateService/axiom
# 20        https://github.com/hniu-tamu/geoshaha-haoyu
# 21            https://github.com/pavloae/georef-ar-py
# 22   https://github.com/OCA/stock-logistics-warehouse
# 23                     https://github.com/edsaav/nail
# 24  https://github.com/circles-zone/local-logger-p...
#
#                                              homepage     earliest_release
# 0                                                 NaN  2023-04-25T22:54:54  \
# 1         https://gitee.com/UnderTurrets/pixiv-spider  2023-04-23T13:32:51
# 2                                                 NaN  2023-04-24T08:11:28
# 3            https://github.com/Arsybai/jawa-language  2023-04-25T00:08:33
# 4                                                 NaN  2023-04-26T07:46:17
# 5                                                 NaN  2023-04-25T13:26:24
# 6        https://github.com/MihailSalnikov/EvaluateQA  2023-04-26T12:10:16
# 7   https://pypi.org/project/certora-cli-alpha-she...  2023-04-28T13:28:28
# 8   https://github.com/Simply-Artificial/NodeArchi...  2023-04-27T17:03:58
# 9   https://github.com/xreef/EByte_LoRa_E22_raspbe...  2023-04-25T17:31:17
# 10           https://github.com/NCI-CIDC/cidc-schemas  2023-04-25T15:04:06
# 11                                                NaN  2023-04-26T13:51:25
# 12             https://github.com/subhranil2605/nb2py  2023-04-24T06:57:44
# 13           https://github.com/lpm0073/secure-logger  2023-04-25T19:12:14
# 14             https://github.com/sluijs/tunnelvision  2023-04-25T21:30:02
# 15            https://github.com/bridgecrewio/checkov  2023-04-26T19:07:36
# 16                                                NaN  2023-04-24T09:25:57
# 17        https://github.com/jnsebgosselin/qtapputils  2023-04-26T20:53:45
# 18        https://github.com/hiroalchem/napari-SAM4IS  2023-04-28T06:28:50
# 19         https://github.com/AusClimateService/axiom  2023-04-29T06:08:25
# 20        https://github.com/hniu-tamu/geoshaha-haoyu  2023-04-25T21:37:16
# 21                                                NaN  2023-04-28T16:07:40
# 22   https://github.com/OCA/stock-logistics-warehouse  2023-04-25T08:51:30
# 23                     https://github.com/edsaav/nail  2023-04-29T05:15:42
# 24  https://github.com/circles-zone/local-logger-p...  2023-04-27T21:38:11
#
#     gh_url_check                                             github
# 0            0.0                                                NaN
# 1            0.0                                                NaN
# 2            NaN                                                NaN
# 3            1.0           https://github.com/Arsybai/jawa-language
# 4            NaN                                                NaN
# 5            1.0            https://github.com/GaNiziolek/FoccoERPy
# 6            1.0       https://github.com/MihailSalnikov/EvaluateQA
# 7            0.0                                                NaN
# 8            1.0  https://github.com/Simply-Artificial/NodeArchi...
# 9            NaN                                                NaN
# 10           NaN                                                NaN
# 11           1.0  https://github.com/jposada202020/MicroPython_I...
# 12           NaN                                                NaN
# 13           1.0           https://github.com/lpm0073/secure-logger
# 14           NaN                                                NaN
# 15           1.0            https://github.com/bridgecrewio/checkov
# 16           NaN                                                NaN
# 17           1.0        https://github.com/jnsebgosselin/qtapputils
# 18           1.0        https://github.com/hiroalchem/napari-SAM4IS
# 19           1.0         https://github.com/AusClimateService/axiom
# 20           1.0        https://github.com/hniu-tamu/geoshaha-haoyu
# 21           1.0            https://github.com/pavloae/georef-ar-py
# 22           1.0   https://github.com/OCA/stock-logistics-warehouse
# 23           1.0                     https://github.com/edsaav/nail
# 24           NaN                                                NaN

# %%
df.to_csv("check-github-url.csv", index=False)
